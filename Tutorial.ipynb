# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("./Dataset/TCPD_AE_West_Bengal_2023-8-16.csv", low_memory=False)

# %%
df.head()
# Out:
#     State_Name  Assembly_No  Constituency_No  Year  month  DelimID  Poll_No  \
# 0  West_Bengal           17                1  2021    5.0        4        0
# 1  West_Bengal           17                1  2021    5.0        4        0
# 2  West_Bengal           17                1  2021    5.0        4        0
# 3  West_Bengal           17                1  2021    5.0        4        0
# 4  West_Bengal           17                1  2021    5.0        4        0
#
#    Position                Candidate  Sex Party    Votes   Age Candidate_Type  \
# 0         1  ADHIKARY PARESH CHANDRA    M  AITC  99338.0  68.0            NaN
# 1         2             DADHIRAM RAY    M   BJP  84653.0  38.0            NaN
# 2         3      GOBINDA CHANDRA ROY    M  AIFB   6853.0  62.0            NaN
# 3         4        None Of The Above  NaN  NOTA   2447.0   NaN            NaN
# 4         5         RANJIT KUMAR ROY    M  SUCI   1768.0  37.0            NaN
#
#    Valid_Votes  Electors Constituency_Name Constituency_Type District_Name  \
# 0       198744    227630         MEKLIGANJ                SC   COOCH BEHAR
# 1       198744    227630         MEKLIGANJ                SC   COOCH BEHAR
# 2       198744    227630         MEKLIGANJ                SC   COOCH BEHAR
# 3       198744    227630         MEKLIGANJ                SC   COOCH BEHAR
# 4       198744    227630         MEKLIGANJ                SC   COOCH BEHAR
#
#             Sub_Region  N_Cand  Turnout_Percentage  Vote_Share_Percentage  \
# 0  JALPAIGURI DIVISION       9               87.31                  49.98
# 1  JALPAIGURI DIVISION       9               87.31                  42.59
# 2  JALPAIGURI DIVISION       9               87.31                   3.45
# 3  JALPAIGURI DIVISION       9               87.31                   1.23
# 4  JALPAIGURI DIVISION       9               87.31                   0.89
#
#   Deposit_Lost   Margin  Margin_Percentage  ENOP         pid Party_Type_TCPD  \
# 0           no  14685.0               7.39  2.33  AEWB102177             NaN
# 1           no  77800.0              39.15  2.33  AEWB100207             NaN
# 2          yes   4406.0               2.22  2.33  AEWB102301             NaN
# 3          NaN    679.0               0.34  2.33         NaN             NaN
# 4          yes    743.0               0.37  2.33  AEWB125019             NaN
#
#    Party_ID  last_poll  Contested Last_Party  Last_Party_ID  \
# 0   18228.0       True        6.0       AIFB         3040.0
# 1    1605.0       True        2.0        BJP         1605.0
# 2    3040.0       True        2.0       AIFB         3040.0
# 3    5897.0       True        NaN        NaN            NaN
# 4    8082.0       True        1.0        NaN            NaN
#
#   Last_Constituency_Name Same_Constituency Same_Party  No_Terms Turncoat  \
# 0              MEKLIGANJ              True      False       5.0     True
# 1              MEKLIGANJ              True       True       0.0    False
# 2             JALPAIGURI             False       True       0.0    False
# 3                    NaN               NaN        NaN       NaN      NaN
# 4                    NaN               NaN        NaN       0.0    False
#
#   Incumbent Recontest MyNeta_education      TCPD_Prof_Main  \
# 0     False      True        12th Pass  Retired or Pension
# 1     False      True        12th Pass            Business
# 2     False     False    Post Graduate               Other
# 3       NaN       NaN              NaN                 NaN
# 4     False     False         Graduate         Social Work
#
#   TCPD_Prof_Main_Desc TCPD_Prof_Second TCPD_Prof_Second_Desc  \
# 0                 NaN              NaN                   NaN
# 1                 NaN      Agriculture                   NaN
# 2                 NaN              NaN                   NaN
# 3                 NaN              NaN                   NaN
# 4                 NaN              NaN                   NaN
#
#                   Election_Type
# 0  State Assembly Election (AE)
# 1  State Assembly Election (AE)
# 2  State Assembly Election (AE)
# 3  State Assembly Election (AE)
# 4  State Assembly Election (AE)

# %%
df.shape
# Out:
# (23917, 47)

# %%
df.isna().sum()
# Out:
# State_Name                    0
# Assembly_No                   0
# Constituency_No               0
# Year                          0
# month                       627
# DelimID                       0
# Poll_No                       0
# Position                      0
# Candidate                     0
# Sex                         317
# Party                        16
# Votes                        10
# Age                       16276
# Candidate_Type            18392
# Valid_Votes                   0
# Electors                      0
# Constituency_Name             0
# Constituency_Type             0
# District_Name                 2
# Sub_Region                17228
# N_Cand                        0
# Turnout_Percentage            0
# Vote_Share_Percentage        11
# Deposit_Lost                604
# Margin                        8
# Margin_Percentage            11
# ENOP                         11
# pid                         604
# Party_Type_TCPD            2468
# Party_ID                     60
# last_poll                     0
# Contested                   604
# Last_Party                17645
# Last_Party_ID             17645
# Last_Constituency_Name    17645
# Same_Constituency         17645
# Same_Party                17645
# No_Terms                    604
# Turncoat                    604
# Incumbent                   604
# Recontest                   604
# MyNeta_education          17972
# TCPD_Prof_Main            17949
# TCPD_Prof_Main_Desc       22227
# TCPD_Prof_Second          23614
# TCPD_Prof_Second_Desc     23826
# Election_Type                 0
# dtype: int64

# %%
df["Sex"].unique()
# Out:
# array(['M', nan, 'F', 'male', 'MALE', 'female', 'NOTA', 'FEMALE'],
#       dtype=object)

# %%
df["Party"].unique()
# Out:
# array(['AITC', 'BJP', 'AIFB', 'NOTA', 'SUCI', 'BSP', 'IND',
#        'Kamatapur People’s Party (United)', 'Amra Bangalee', 'CPM', 'INC',
#        'LJP', nan, 'United Socialist Party', 'RSP', 'JD(U)',
#        'Bahujan Mukti Party', 'NPP', 'Samajwadi Jan Parishad',
#        'Bhartiya Tribal Party', 'CPI(ML)(L)',
#        'Republican Party of India (A)', "Progressive People's Party",
#        'RPI(A)', 'CPI', 'AIMIM',
#        'Communist Party of India (Marxist-Leninist) Red Star',
#        'Ambedkarite Party of India', 'Welfare Party Of India', 'RSSCMJP',
#        'IUML', 'Party for Democratic Socialism',
#        'Jamat-E-Seratul Mustakim', 'SDPI', 'JSTDVPMTP', 'BAHUMP',
#        'Bahujan Maha Party', 'Democratic Socialist Party of India',
#        'Justice and Development Party,', 'HAM',
#        'Purvanchal Mahapanchayat', 'Bharatiya Nyay-Adhikar Raksha Party',
#        'Jan Sangh Party', 'Socialist Party (India)',
#        'New Democratic Party of India', 'Guru Chand Mukti Morcha',
#        'Revolutionary Socialist Party of India(Marxist)',
#        'National Republic Party Of India', 'Lok Samya Party',
#        'Right to Recall Party', 'All India Minorities Front',
#        'Bharatiya Momin Front', 'West Bengal Socialist Party',
#        'Akhil Bharat Hindu Mahasabha', 'Sajag Samaj Party',
#        'Vikas India Party', 'Indian Unity Centre',
#        'Humanity Universal Motion Party', 'Bharateeya Manavadhikar party',
#        'AJSUP', 'Mulnibasi Party of India', 'Paradise Party',
#        'Rashtravadi Janata Party', 'AMB', 'KPPU', 'WPOI', 'JMM', 'ABGL',
#        'GOJAM', 'GRAC', 'ABHM', 'BMUP', 'JDP', 'SP', 'SWJP', 'CPIM',
#        'HKRD', 'SHS', 'JESM', 'PDS', 'MPOI', 'GMM', 'NDPOI', 'TRMRPPI',
#        'AAAP', 'RAJSP', 'IUC', 'RLD', 'RJD', 'JD(S)', 'MHB', 'STPI',
#        'FDLP', 'NCP', 'BHNP', 'DSP(P)', 'JKP(N)', 'AKBJHP', 'JHAP',
#        'CPI(Marxist)', 'SP(I)', 'RCPI(R)', 'SUCI(Communist)',
#        'CPM(Marxist)', 'All India Jana Andolan Party',
#        'Indian Democratic Republican Front', 'Gorkha Rashtriya Congress',
#        'Akhil Bharatiya Gorkha League',
#        'Indian Democratic People’s Party', 'RPI', 'PDCI', 'IPFB', 'RADP',
#        'GNLF', 'KPP', 'PBRML', 'MUL', 'IJP', 'NSBP', 'SAP', 'AIMF',
#        'RJNP', 'PPIS', 'JGP', 'SJP(R)', 'INL', 'AJSU', 'JVM', 'JP',
#        'RJSP', 'JD', 'AIUD', 'CPI(L)', 'SUCI(C)', 'CPI(MAXIST)', 'SJP',
#        'CPI(M)(L)', 'WBSP', 'RSMP', 'AB', 'CPI(ML)', 'JUM', 'SHSP',
#        'MLKSC', 'IATC', 'IIND', 'DSP', 'FBL', 'MCPI(S)', 'LJNSP', 'PBGM',
#        'BMF', 'JKP', 'FB(S)', 'AIIC(T)', 'BMSM', 'ABJS', 'AICDBPP',
#        'IDPP', 'HJKP', 'JMM(M)', 'WBTC', 'IPF', 'MCPI', 'HMS', 'WPI',
#        'DMM', 'RCPI', 'BDD', 'DDP', 'BPI', 'BJS', 'INC(O)', 'LKD', 'BD',
#        'ICS(SCS)', 'UCPI', 'DSP(PC)', 'HJP', 'RCPI(RB)', 'RCPI(GS)',
#        'SUC', 'JNP', 'CPI (ML)', 'ICS', 'IGL', 'RCI', 'BBC', 'JKD', 'MFB',
#        'INC(I)', 'JNP(S)', 'NCO', 'SOP', 'PBI', 'RSM', 'IAL', 'BIB',
#        'BAC', 'PSP', 'SSP', 'PML', 'SOC', 'SML', 'LSS', 'NDF', 'SWA',
#        'BJD', 'MIL', 'PBK', 'FB', 'GL', 'JS', 'SBP', 'COM'], dtype=object)

# %%
len(df["Party"].unique())
# Out:
# 215

# %%
df[["Year", "Assembly_No", "Party","Votes"]].groupby(["Year", "Party", "Assembly_No"]).mean()
# Out:
#                                                      Votes
# Year Party                       Assembly_No
# 1962 CPI                         3            16460.924138
#      FB                          3            12973.470588
#      GL                          3             9519.000000
#      HMS                         3             3045.520000
#      INC                         3            17946.333333
# ...                                                    ...
# 2021 Socialist Party (India)     17             706.000000
#      United Socialist Party      17             743.166667
#      Vikas India Party           17             154.000000
#      Welfare Party Of India      17            1141.000000
#      West Bengal Socialist Party 17            1081.500000
#
# [640 rows x 1 columns]

# %%
# fillna

df["Sex"] = df["Sex"].fillna("NOTA")

# %%
df["Sex"].isna().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['State_Name', 'Assembly_No', 'Constituency_No', 'Year', 'month',
#        'DelimID', 'Poll_No', 'Position', 'Candidate', 'Sex', 'Party', 'Votes',
#        'Age', 'Candidate_Type', 'Valid_Votes', 'Electors', 'Constituency_Name',
#        'Constituency_Type', 'District_Name', 'Sub_Region', 'N_Cand',
#        'Turnout_Percentage', 'Vote_Share_Percentage', 'Deposit_Lost', 'Margin',
#        'Margin_Percentage', 'ENOP', 'pid', 'Party_Type_TCPD', 'Party_ID',
#        'last_poll', 'Contested', 'Last_Party', 'Last_Party_ID',
#        'Last_Constituency_Name', 'Same_Constituency', 'Same_Party', 'No_Terms',
#        'Turncoat', 'Incumbent', 'Recontest', 'MyNeta_education',
#        'TCPD_Prof_Main', 'TCPD_Prof_Main_Desc', 'TCPD_Prof_Second',
#        'TCPD_Prof_Second_Desc', 'Election_Type'],
#       dtype='object')

# %%
df.Candidate_Type.unique()
# Out:
# array([nan, 'GENERAL', 'SC', 'GEN', 'ST'], dtype=object)

# %%
df = df[['State_Name', 'Assembly_No', 'Constituency_No', 'Year',
       'Position', 'Candidate', 'Sex', 'Party', 'Votes',
       'Age', 'Candidate_Type', 'Valid_Votes', 'Electors', 'Constituency_Name',
       'Constituency_Type', 'District_Name', 'N_Cand', 'Turnout_Percentage',
       'Vote_Share_Percentage', 'Deposit_Lost', 'Margin', 'Margin_Percentage',
       'ENOP', 'last_poll', 'Contested',
       'No_Terms', 'Turncoat', 'Incumbent',
       'Recontest', 'MyNeta_education']]

# %%
df.head()
# Out:
#     State_Name  Assembly_No  Constituency_No  Year  Position  \
# 0  West_Bengal           17                1  2021         1
# 1  West_Bengal           17                1  2021         2
# 2  West_Bengal           17                1  2021         3
# 3  West_Bengal           17                1  2021         4
# 4  West_Bengal           17                1  2021         5
#
#                  Candidate   Sex Party    Votes   Age Candidate_Type  \
# 0  ADHIKARY PARESH CHANDRA     M  AITC  99338.0  68.0            NaN
# 1             DADHIRAM RAY     M   BJP  84653.0  38.0            NaN
# 2      GOBINDA CHANDRA ROY     M  AIFB   6853.0  62.0            NaN
# 3        None Of The Above  NOTA  NOTA   2447.0   NaN            NaN
# 4         RANJIT KUMAR ROY     M  SUCI   1768.0  37.0            NaN
#
#    Valid_Votes  Electors Constituency_Name Constituency_Type District_Name  \
# 0       198744    227630         MEKLIGANJ                SC   COOCH BEHAR
# 1       198744    227630         MEKLIGANJ                SC   COOCH BEHAR
# 2       198744    227630         MEKLIGANJ                SC   COOCH BEHAR
# 3       198744    227630         MEKLIGANJ                SC   COOCH BEHAR
# 4       198744    227630         MEKLIGANJ                SC   COOCH BEHAR
#
#    N_Cand  Turnout_Percentage  Vote_Share_Percentage Deposit_Lost   Margin  \
# 0       9               87.31                  49.98           no  14685.0
# 1       9               87.31                  42.59           no  77800.0
# 2       9               87.31                   3.45          yes   4406.0
# 3       9               87.31                   1.23          NaN    679.0
# 4       9               87.31                   0.89          yes    743.0
#
#    Margin_Percentage  ENOP  last_poll  Contested  No_Terms Turncoat Incumbent  \
# 0               7.39  2.33       True        6.0       5.0     True     False
# 1              39.15  2.33       True        2.0       0.0    False     False
# 2               2.22  2.33       True        2.0       0.0    False     False
# 3               0.34  2.33       True        NaN       NaN      NaN       NaN
# 4               0.37  2.33       True        1.0       0.0    False     False
#
#   Recontest MyNeta_education
# 0      True        12th Pass
# 1      True        12th Pass
# 2     False    Post Graduate
# 3       NaN              NaN
# 4     False         Graduate

# %%
df[["Candidate", "Sex"]].groupby("Sex").count().plot(kind="bar")
# Out:
# <Axes: xlabel='Sex'>

# %%
df.loc[df["Sex"]=="MALE", "Sex"] = "M"

# %%
df.loc[df["Sex"]=="Male", "Sex"] ="M"
df.loc[df["Sex"]=="MALE", "Sex"] ="M"
df.loc[df["Sex"]=="male", "Sex"] ="M"
df.loc[df["Sex"]=="female", "Sex"] ="F"
df.loc[df["Sex"]=="FEMALE", "Sex"] ="F"
df["Sex"] = df["Sex"].fillna("NOTA")

# %%
df[["Candidate", "Sex"]].groupby("Sex").count().plot(kind="barh", figsize=(16,8), xlabel="Sex", ylabel="Count of Candidates")
# Out:
# <Axes: ylabel='Sex'>
